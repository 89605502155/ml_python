# %%
import numpy as np
a=np.array([[1,2,3],[1,2,3]])
type(a)
# Out:
# numpy.ndarray

# %%
b=np.array([[[1,2,3],[1,2,3]],[[1,2,3],[1,2,3]]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
from dataset_model import Dataset_model

# %%
a=Dataset_model(np.array([1]),np.array([1]),np.array([1]),np.array([1]))

# %%
type(a)
# Out:
# dataset_model.Dataset_model

# %%
type_b={
    'Sectrun':numpy.ndarray
    Consentration:numpy.ndarray
    Emission_wale:numpy.ndarray
    Exitation_wale:numpy.ndarray}

# %%
from open import Open_file

# %%
b=Open_file()
a=b.main(file_name='syn')

# %%
from draw_simple_spectrum import Draw_simple_spectrum

# %%
paint=Draw_simple_spectrum(a,0)

# %%
paint.main(save=True,size_img=(15,7))
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/draw_simple_spectrum.py:72: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/draw_simple_spectrum.py:73: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
import pandas as pd

# %%
df=pd.DataFrame(a.Consentration,columns=a.Name_of_column_list)

# %%
df.to_excel('excel/y_syn.xlsx',sheet_name="y_syn",index=False, float_format='%.4f',header=a.Name_of_column_list)

# %%
df1=pd.read_excel('best_param.ods', engine="odf",header=None,names=['name','n','a'])

# %%
df1[df1.name=='syn']
# Out:
#   name  n     a
# 0  syn  4  10.0
# 1  syn  4  10.0
# 2  syn  4   1.0
# 3  syn  4   1.0

# %%
df2=df1[df1.name=='syn']

# %%
df2
# Out:
#   name  n     a
# 0  syn  4  10.0
# 1  syn  4  10.0
# 2  syn  4   1.0
# 3  syn  4   1.0

# %%
for i,j in df2.iterrows():
    print(j['n'],type(j['a']),i)
# Out:
# 4 <class 'float'> 0
# 4 <class 'float'> 1
# 4 <class 'float'> 2
# 4 <class 'float'> 3

# %%
from draw_simple_spectrum import Draw_simple_spectrum as ss

# %%
v=ss(data= a,number_of_spectrum_for_draw=1)

# %%
v.main(save=False)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/draw_simple_spectrum.py:57: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/draw_simple_spectrum.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
from centering_and_cross_validation import Cross_validation as cv

# %%
mod=cv(data=a,number_of_column=0)

# %%
res=mod.main()

# %%
res.Const_centering_concentraton
# Out:
# 39.99465770898121

# %%
res.Test_concentration,
# Out:
# (array([-3.08549775, -4.27022686,  2.1530446 , -6.65260834,  9.41508832]),)

# %%
res.Train_spectrum.shape
# Out:
# (30, 206, 52)

# %%
from npls import npls

# %%
type(npls())
# Out:
# npls.npls.npls

# %%
from training_algorithm import Training
import numpy as np

# %%
mm=Training(file_name='syn',number_of_column=1,number_of_components=[4],l2_coefs=np.array([400]))

# %%
response=mm.main()

# %%
def img_save_file_name(self):
        return 'loadings/'+self.file_name+'/'+self.names[self.file_name][self.number_of_column]
    
    def easy_plot(resp):
        fig = plt.figure(figsize=(17, 10.5),constrained_layout=True)
        plt.title(self.file_name+" "+self.names[self.file_name][self.number_of_column],loc='center')
        spec = fig.add_gridspec(ncols=2, nrows=1)
        row=0
        for col in range(2):
            ax = fig.add_subplot(spec[row, col])
            if col==0:
                for i in range(resp[2]['n_components']):
                    ax.plot(resp[3].w_i[i,:,0],label=str(i))
                ax.set_title('Excitation')
            elif col==1:
                for i in range(resp[2]['n_components']):
                    ax.plot(resp[3].w_k[i,:,0],label=str(i))
                ax.set_title('Emission')
            ax.legend()
        plt.savefig(self.img_save_file_name()+'.pdf', format='pdf', dpi=300,bbox_inches='tight')
        plt.savefig(self.img_save_file_name()+'.jpg', format='jpg', dpi=300,bbox_inches='tight')
        plt.savefig(self.img_save_file_name()+".svg", format="svg",bbox_inches='tight')
        plt.show()

# %%
response[1]['mean_test_r2']
# Out:
# array([0.72989393, 0.97582424, 0.99391967, 1.        ])

# %%
np.argmin(response[1]['mean_test_mse'])
# Out:
# 3

# %%
response[1]['mean_test_r2']
# Out:
# 9.869664883299265

# %%
response[2]['n_components']

# %%
response[3].w_k
# Out:
# array([[[-1.35992000e-03],
#         [-1.45503217e-03],
#         [-1.55643912e-03],
#         ...,
#         [ 1.29944628e-03],
#         [ 1.25086107e-03],
#         [ 1.20354734e-03]],
#
#        [[-1.23212994e-03],
#         [-1.42060818e-03],
#         [-1.63056212e-03],
#         ...,
#         [-1.64262748e-02],
#         [-1.57921559e-02],
#         [-1.51764263e-02]],
#
#        [[-6.39092514e-03],
#         [-7.24517450e-03],
#         [-8.19179524e-03],
#         ...,
#         [ 2.60836711e-03],
#         [ 2.50703630e-03],
#         [ 2.40871018e-03]],
#
#        [[ 2.30012235e-05],
#         [ 2.60592524e-05],
#         [ 2.94471008e-05],
#         ...,
#         [-1.71323787e-05],
#         [-1.52141474e-05],
#         [-1.35026018e-05]]])

# %%
import matplotlib.pyplot as plt
from pathlib import Path

# %%
plt.plot([1,2,4])
Path(".loadings/syn").mkdir(parents=True, exist_ok=True)
plt.savefig( 'loadings/syn/first.jpg')

# %%
def easy_plot(resp):
        fig = plt.figure(figsize=(17, 10.5),constrained_layout=True)
        plt.title("jj",loc='center')
        spec = fig.add_gridspec(ncols=2, nrows=1)
        row=0
        for col in range(2):
            ax = fig.add_subplot(spec[row, col])
            if col==0:
                for i in range(resp[2]['n_components']):
                    ax.plot(resp[3].w_i[i,:,0],label=str(i))
                ax.set_title('Excitation')
            elif col==1:
                for i in range(resp[2]['n_components']):
                    ax.plot(resp[3].w_k[i,:,0],label=str(i))
                ax.set_title('Emission')
            ax.legend()
        plt.show()

# %%
easy_plot(response)

# %%
response[2]['a']
# Out:
# 400

# %%
np.logspace(-3,15,19)
# Out:
# array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04,
#        1.e+05, 1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10, 1.e+11, 1.e+12,
#        1.e+13, 1.e+14, 1.e+15])

# %%
np.logspace(10,10,1)
# Out:
# array([1.e+10])

# %%
from logic_of_training import Logic_of_training

# %%
ppp=Logic_of_training('syn',0)

# %%
resp4=ppp.main()

# %%
resp4
# Out:
# [10.0, 4, 3.2243700631127025e-10, 1.0]

# %%
names={
            'syn':['first','second','third','fourth'],
            'asmund':['catechol','hydroquinone','indole','resorcinol','tryptophane','tyrosine'],
            'dorrit':['hydroquinone','tryptophane','phenylalanine','DOPA'],
            'marat':['humic','tyrosine','tryptophane']
        }

# %%
for i in names.keys():
    for j in range(len(names[i])):
        if (i=='dorrit' and j==1):
            ppp=Logic_of_training(i,j)
            resp4=ppp.main()
            print(i,j,resp4)
# Out:
# dorrit 1 [100000.0, 5, 0.03205404704795326, 0.8545281751781933]

# %%
list(names.keys())[2]
# Out:
# 'dorrit'

# %%
names['syn'][0]
# Out:
# 'first'

# %%
from predict_reference_plot import Predict_reference_plot

# %%
a=Predict_reference_plot()

# %%
m=a.main()
