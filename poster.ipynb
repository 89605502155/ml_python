# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('none_interpolation/X/35.txt',sep='\t')

# %%
data.index,data.columns
# Out:
# (Index([240, 242, 244, 246, 248, 250, 252, 254, 256, 258,
#         ...
#         632, 634, 636, 638, 640, 642, 644, 646, 648, 650],
#        dtype='int64', length=206),
#  Index(['230', '235', '240', '245', '250', '255', '260', '265', '270', '275',
#         '280', '285', '290', '295', '300', '305', '310', '315', '320', '325',
#         '330', '335', '340', '345', '350', '355', '360', '365', '370', '375',
#         '380', '385', '390', '395', '400', '405', '410', '415', '420', '425',
#         '430', '435', '440', '445', '450', '455', '460', '465', '470', '475',
#         '480', '485', '490', '495', '500'],
#        dtype='object'))

# %%
exitt=np.array([int(i) for i in data.columns])

# %%
from dataset_model import Dataset_model as dm

# %%
d=dm(Sectrun=np.array([data]),Consentration=np.array([0]),
     Emission_wale=np.array(data.index),Exitation_wale=exitt,Name_of_column_list=['Без интерполирования'])

# %%
d.Sectrun.shape
# Out:
# (1, 206, 55)

# %%
from paint_scripts.draw_simple_spectrum_rus import Draw_simple_spectrum as paint_

# %%
mod=paint_(data=d,number_of_spectrum_for_draw=0,number_column_for_concentration_for_dm=0)

# %%
mod.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
from open import Open_file

# %%
b=Open_file()
a=b.main(file_name='marat')

# %%
mod_=paint_(data=a,number_of_spectrum_for_draw=34,number_column_for_concentration_for_dm=0)

# %%
mod_.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
dd=np.nan_to_num(d.Sectrun[0,:,3:],nan=0.0)

# %%
delta=np.array( dd-a.Sectrun[34,:,:]).reshape([206,52])

# %%
mask=delta>=0.04

# %%
kk=a.Sectrun[34,:,:].copy()

# %%
kk[mask]=np.nan

# %%
d2=dm(Sectrun=np.array([kk]).reshape([1,206,52]),Consentration=np.array([0]),
     Emission_wale=a.Emission_wale,Exitation_wale=a.Exitation_wale,Name_of_column_list=['промежуток'])

# %%
mod_2=paint_(data=d2,number_of_spectrum_for_draw=0,number_column_for_concentration_for_dm=0)

# %%
mod_2.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
a_syn=b.main(file_name='syn')

# %%
mod_syn=paint_(data=a_syn,number_of_spectrum_for_draw=0,number_column_for_concentration_for_dm=0)

# %%
mod_syn.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
a_rin=b.main(file_name='asmund')

# %%
mod_rin=paint_(data=a_rin,number_of_spectrum_for_draw=0,number_column_for_concentration_for_dm=0)

# %%
mod_rin.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
# a_baunsgaard=b.main(file_name='dorrit')
a_baunsgaard=b.main(file_name='dorrit_all')

# %%
mod_baunsgaard=paint_(data=a_baunsgaard,number_of_spectrum_for_draw=10,number_column_for_concentration_for_dm=0)

# %%
mod_baunsgaard.main(save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %%
mod_baunsgaard.main()
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:74: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_simple_spectrum_rus.py:75: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=label_x_number_size)

# %% [markdown]
# # рисую пример зашумлённой и незашумлённой нагрузок

# %%
from gzip import open # NB: overrides standard open()
import pickle as pkl
import pandas as pd
import warnings 
from glob import glob
import os

# %%
test_load=pkl.load(open('smoother_of_loadings.pkl.gz','rb'))

# %%
test_load.keys()
# Out:
# dict_keys(['loadings', 'information_about_load', 'snr_evklid_second', 'is_smooth'])

# %%
from npls import npls
from signal_noise import signal_noise

# %%
model_npls_good=npls(excitation_wavelenth=a_syn.Exitation_wale,
                emission_wavelenth=a_syn.Emission_wale,n_components=2)
model_npls_good.fit(a_syn.Sectrun,a_syn.Consentration[:,2])
# Out:
# npls(emission_wavelenth=array([250., 251., 252., 253., 254., 255., 256., 257., 258., 259., 260.,
#        261., 262., 263., 264., 265., 266., 267., 268., 269., 270., 271.,
#        272., 273., 274., 275., 276., 277., 278., 279., 280., 281., 282.,
#        283., 284., 285., 286., 287., 288., 289., 290., 291., 292., 293.,
#        294., 295., 296., 297., 298., 299., 300., 301., 302., 303., 304.,
#        305., 306., 307., 308., 309., 310., 311., 312., 313....
#        569., 570., 571., 572., 573., 574., 575., 576., 577., 578., 579.,
#        580., 581., 582., 583., 584., 585., 586., 587., 588., 589., 590.,
#        591., 592., 593., 594., 595., 596., 597., 598., 599., 600.]),
#      excitation_wavelenth=array([230., 235., 240., 245., 250., 255., 260., 265., 270., 275., 280.,
#        285., 290., 295., 300., 305., 310., 315., 320., 325., 330., 335.,
#        340., 345., 350., 355., 360., 365., 370., 375., 380., 385., 390.,
#        395., 400.]))

# %%
import matplotlib.pyplot as plt

# %%
len(model_npls_good.bf_array[0]),model_npls_good.bf_array
# Out:
# (1,
#  [array([[0.00010139]]), array([[6.16203586e-06],
#          [1.86332352e-04]])])

# %%
for i in range(2):
    plt.plot( model_npls_good.w_k[i,:,0])
    plt.show()

# %%
model_npls_bad=npls(excitation_wavelenth=a.Exitation_wale,
                emission_wavelenth=a.Emission_wale,n_components=12)
model_npls_bad.fit(a.Sectrun,a.Consentration[:,0])
# Out:
# npls(emission_wavelenth=array([240., 242., 244., 246., 248., 250., 252., 254., 256., 258., 260.,
#        262., 264., 266., 268., 270., 272., 274., 276., 278., 280., 282.,
#        284., 286., 288., 290., 292., 294., 296., 298., 300., 302., 304.,
#        306., 308., 310., 312., 314., 316., 318., 320., 322., 324., 326.,
#        328., 330., 332., 334., 336., 338., 340., 342., 344., 346., 348.,
#        350., 352., 354., 356., 358., 360., 362., 364., 366....
#        614., 616., 618., 620., 622., 624., 626., 628., 630., 632., 634.,
#        636., 638., 640., 642., 644., 646., 648., 650.]),
#      excitation_wavelenth=array([245., 250., 255., 260., 265., 270., 275., 280., 285., 290., 295.,
#        300., 305., 310., 315., 320., 325., 330., 335., 340., 345., 350.,
#        355., 360., 365., 370., 375., 380., 385., 390., 395., 400., 405.,
#        410., 415., 420., 425., 430., 435., 440., 445., 450., 455., 460.,
#        465., 470., 475., 480., 485., 490., 495., 500.]),
# ...

# %%
for i in range(12):
    plt.plot( model_npls_bad.w_k[i,:,0])
    plt.show()

# %%
plt.plot( model_npls_bad.w_k[10,:,0])
plt.show()

# %%
from paint_scripts.paint_one_loading_and_her_snr_rus import Plot_one_loading_and_her_snr_rus as ppp

# %%
import importlib
import sys
importlib.reload(sys.modules['paint_scripts.paint_one_loading_and_her_snr_rus'])
from paint_scripts.paint_one_loading_and_her_snr_rus import Plot_one_loading_and_her_snr_rus as ppp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 import importlib
#       2 import sys
# ----> 3 importlib.reload(sys.modules['paint_scripts.paint_one_loading_and_her_snr_rus'])
#       4 from paint_scripts.paint_one_loading_and_her_snr_rus import Plot_one_loading_and_her_snr_rus as ppp
#
# KeyError: 'paint_scripts.paint_one_loading_and_her_snr_rus'

# %%
snr_=signal_noise()

# %%
plotter=ppp()
plotter.painter(snr_bad=snr_.main(signal=model_npls_bad.w_k[10,:,0],x=a.Emission_wale),
                snr_good=snr_.main(signal=model_npls_good.w_k[1,:,0]*(-1.5),x=a_syn.Emission_wale),
                loading_good=model_npls_good.w_k[1,:,0]*(-1.5),
                loading_bad=model_npls_bad.w_k[10,:,0],wave_lenghts_bad=a.Emission_wale,
                wave_lenghts_good=a_syn.Emission_wale,save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_one_loading_and_her_snr_rus.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=self.ax_label_number_font)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_one_loading_and_her_snr_rus.py:33: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=self.ax_label_number_font)

# %%
model_npls_without_reg=npls(excitation_wavelenth=a.Exitation_wale,
                emission_wavelenth=a.Emission_wale,n_components=11,a=0)
model_npls_without_reg.fit(a.Sectrun,a.Consentration[:,0])
# Out:
# npls(a=0,
#      emission_wavelenth=array([240., 242., 244., 246., 248., 250., 252., 254., 256., 258., 260.,
#        262., 264., 266., 268., 270., 272., 274., 276., 278., 280., 282.,
#        284., 286., 288., 290., 292., 294., 296., 298., 300., 302., 304.,
#        306., 308., 310., 312., 314., 316., 318., 320., 322., 324., 326.,
#        328., 330., 332., 334., 336., 338., 340., 342., 344., 346., 348.,
#        350., 352., 354., 356., 358., 360., 362., 364.,...
#        614., 616., 618., 620., 622., 624., 626., 628., 630., 632., 634.,
#        636., 638., 640., 642., 644., 646., 648., 650.]),
#      excitation_wavelenth=array([245., 250., 255., 260., 265., 270., 275., 280., 285., 290., 295.,
#        300., 305., 310., 315., 320., 325., 330., 335., 340., 345., 350.,
#        355., 360., 365., 370., 375., 380., 385., 390., 395., 400., 405.,
#        410., 415., 420., 425., 430., 435., 440., 445., 450., 455., 460.,
#        465., 470., 475., 480., 485., 490., 495., 500.]),
# ...

# %%
model_npls_with_reg=npls(excitation_wavelenth=a.Exitation_wale,
                emission_wavelenth=a.Emission_wale,n_components=11,a=10)
model_npls_with_reg.fit(a.Sectrun,a.Consentration[:,0])
# Out:
# npls(a=10,
#      emission_wavelenth=array([240., 242., 244., 246., 248., 250., 252., 254., 256., 258., 260.,
#        262., 264., 266., 268., 270., 272., 274., 276., 278., 280., 282.,
#        284., 286., 288., 290., 292., 294., 296., 298., 300., 302., 304.,
#        306., 308., 310., 312., 314., 316., 318., 320., 322., 324., 326.,
#        328., 330., 332., 334., 336., 338., 340., 342., 344., 346., 348.,
#        350., 352., 354., 356., 358., 360., 362., 364....
#        614., 616., 618., 620., 622., 624., 626., 628., 630., 632., 634.,
#        636., 638., 640., 642., 644., 646., 648., 650.]),
#      excitation_wavelenth=array([245., 250., 255., 260., 265., 270., 275., 280., 285., 290., 295.,
#        300., 305., 310., 315., 320., 325., 330., 335., 340., 345., 350.,
#        355., 360., 365., 370., 375., 380., 385., 390., 395., 400., 405.,
#        410., 415., 420., 425., 430., 435., 440., 445., 450., 455., 460.,
#        465., 470., 475., 480., 485., 490., 495., 500.]),
# ...

# %%
plt.plot( np.log10(abs(model_npls_without_reg.bf_array[-1])))
plt.plot(np.log10(abs(model_npls_with_reg.bf_array[-1])))
plt.show()

# %%
import importlib
import sys
importlib.reload(sys.modules['paint_scripts.paint_b_koefs_and_her_l2_rus'])
from paint_scripts.paint_b_koefs_and_her_l2_rus import Plot_b_koefs_and_her_l2_rus as b_koefs_paint

# %%
from paint_scripts.paint_b_koefs_and_her_l2_rus import Plot_b_koefs_and_her_l2_log_rus as b_koefs_paint_log

# %%
b_plot=b_koefs_paint_log()
b_plot.painter(l2=10,loading_bad=np.log10(abs(model_npls_without_reg.bf_array[-1])),
               loading_good=np.log10(abs(model_npls_with_reg.bf_array[-1])),save=True)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_b_koefs_and_her_l2_rus.py:78: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=self.ax_label_number_font)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_b_koefs_and_her_l2_rus.py:79: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_xticklabels(), fontsize=self.ax_label_number_font)

# %%
b_plot=b_koefs_paint()
b_plot.painter(l2=10,loading_bad=model_npls_without_reg.bf_array[-1],
               loading_good=model_npls_with_reg.bf_array[-1],save=False)
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_b_koefs_and_her_l2_rus.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=self.ax_label_number_font)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/paint_b_koefs_and_her_l2_rus.py:35: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(y_lab, fontsize=self.ax_label_number_font)

# %%
np.log10(1e11)
# Out:
# 11.0

# %%
plt.plot( model_npls_without_reg.bf_array[-1])
plt.plot(model_npls_with_reg.bf_array[-1])
plt.show()

# %%
# import importlib
# import sys
# importlib.reload(sys.modules['box_training_algorithm'])
from box_training_algorithm import Box_training_algorithm as box

# %%
# import importlib
# import sys
# importlib.reload(sys.modules['paint_scripts.draw_valid_matrix_rus'])
from paint_scripts.draw_valid_matrix_rus import Draw_valid_matrix_rus as painter

# %%
np.logspace(-3,8,12)
# Out:
# array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04,
#        1.e+05, 1.e+06, 1.e+07, 1.e+08])

# %%
from tqdm import tqdm
import gc,  time
import psutil
import threading

# %%
threshold = 95

# %%
gc.collect()
# Out:
# 14312

# %%
cpu_percent = psutil.cpu_percent(interval=1)
if cpu_percent > threshold:
        print("High CPU load detected. Cooling down...")
        
        # Пауза выполнения программы на 30 секунд
        time.sleep(30)
        
        print("Resuming execution.")
for i in range(4):
    time.sleep(5)
    print(i)
    gc.collect()
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 10
#       8         print("Resuming execution.")
#       9 for i in range(4):
# ---> 10     time.sleep(5)
#      11     print(i)
#      12     gc.collect()
#
# KeyboardInterrupt:

# %%
def calculate():
    # for k in range(6):
    #     print(k)
    #     nodel=box(file_name='asmund',number_of_components=[i for i in range(1,11)],l2_coefs=np.logspace(-5,8,14),
    #         # number_of_column=k,snr=91.7332,norm_func=['evklid'])
    #         number_of_column=k,snr=-1,norm_func=['evklid'])
    #     nodel.calc()
    #     nodel.best_params()
    #     nodel.paint_rmse_p(metrics_name="RMSE_CV",save=True)
    #     nodel.paint_rmse_log(metrics_name="RMSE_CV",save=True)
    #     nodel.paint_q2_cv(metrics_name="Q2_CV",save=True)
    #     time.sleep(25)
    #     gc.collect()
    #     time.sleep(25)
    for k in range(4):
        nodel=box(file_name='dorrit',number_of_components=[i for i in range(1,11)],l2_coefs=np.logspace(-5,8,14),
            # number_of_column=k,snr=91.7332,norm_func=['evklid'])
            number_of_column=k,snr=-1,norm_func=['evklid'])
        nodel.calc()
        nodel.best_params()
        nodel.paint_rmse_p(metrics_name="RMSE_CV",save=True)
        nodel.paint_rmse_log(metrics_name="RMSE_CV",save=True)
        nodel.paint_q2_cv(metrics_name="Q2_CV",save=True)
        time.sleep(25)
        gc.collect()
        time.sleep(25)
    for k in range(3):
        nodel=box(file_name='marat',number_of_components=[i for i in range(1,11)],l2_coefs=np.logspace(-5,8,14),
            # number_of_column=k,snr=91.7332,norm_func=['evklid'])
            number_of_column=k,snr=-1,norm_func=['evklid'])
        nodel.calc()
        nodel.best_params()
        nodel.paint_rmse_p(metrics_name="RMSE_CV",save=True)
        nodel.paint_rmse_log(metrics_name="RMSE_CV",save=True)
        nodel.paint_q2_cv(metrics_name="Q2_CV",save=True)
        time.sleep(25)
        gc.collect()
        time.sleep(25)

# %%
def monitor():
    # Пороговое значение для загрузки процессора (в процентах)
    threshold = 95

    while True:
        # Получаем текущую загрузку процессора
        cpu_percent = psutil.cpu_percent(interval=None)

        # Если текущая загрузка процессора превышает пороговое значение
        if cpu_percent > threshold:
            print("High CPU load detected. Cooling down...")
            time.sleep(30)
            print("Resuming execution.")

        # Пауза перед следующей проверкой
        time.sleep(39)

# %%
calculation_thread = threading.Thread(target=calculate)
calculation_thread.start()


monitor()
# Out:
# High CPU load detected. Cooling down...
# Resuming execution.
# High CPU load detected. Cooling down...
# Resuming execution.
# Q2_CV dorrit 0 0.9250562147803576 10 -4.0
# RMSE_CV  0.008696860625781695
# RMSE_P  0.005246046085076706
# Q2_P  0.9843218411358918
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(x_lab, fontsize=label_x_number_size)
# High CPU load detected. Cooling down...
# ...

# %%
for k in range(4):
    nodel=box(file_name='syn',number_of_components=[i for i in range(1,11)],l2_coefs=np.logspace(-5,8,14),
        # number_of_column=k,snr=91.7332,norm_func=['evklid'])
        number_of_column=k,snr=-1,norm_func=['evklid'])
    nodel.calc()
    nodel.best_params()
    nodel.paint_rmse_p(metrics_name="RMSE_CV",save=True)
    nodel.paint_q2_cv(metrics_name="Q2_CV",save=True)
# Out:
# Q2_CV syn 0 1.0 4 1.0
# RMSE_CV  3.2243700631127025e-10
# RMSE_P  4.366965515606207e-10
# Q2_P  1.0
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_xticklabels(x_lab, fontsize=label_x_number_size)
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=label_y_number_size)
# ...

# %%
nodel=box(file_name='asmund',number_of_components=[i for i in range(1,3)],l2_coefs=np.logspace(2,3,2),
          number_of_column=5,snr=91.7332,norm_func=['evklid'])

# %%
nodel.calc()
# Out:
# /home/ferubkomsu/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 1 fits failed out of a total of 27.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ferubkomsu/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ferubkomsu/Рабочий стол/new_n_pls/box_training_algorithm.py", line 108, in fit
#     response=self.check_smooth_loadings(w_i=w_i[:,0],excitation_wavelenth=self.excitation_wavelenth,
# ...

# %%
nodel.best_params()
nodel.rmse_cv
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/box_training_algorithm.py:253: RuntimeWarning: All-NaN slice encountered
#   best_rmse_cv=np.nanmin(self.rmse_cv)
# /home/ferubkomsu/Рабочий стол/new_n_pls/box_training_algorithm.py:254: RuntimeWarning: All-NaN slice encountered
#   best_q2_cv=np.nanmax(self.q2_cv)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[203], line 1
# ----> 1 nodel.best_params()
#       2 nodel.rmse_cv
#
# File ~/Рабочий стол/new_n_pls/box_training_algorithm.py:256, in Box_training_algorithm.best_params(self)
#     254 best_q2_cv=np.nanmax(self.q2_cv)
#     255 # self.__find_best_param("RMSE_CV",best_rmse_cv,arr=self.rmse_cv)
# --> 256 i,j=self.__find_best_param_q("Q2_CV",best_q2_cv,arr=self.q2_cv)
#     257 rmse_p=self.rmse_p[i][j]
#     258 q2_p=self.q2_p[i][j]
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
nodel.rmse_p,nodel.rmse_cv
# Out:
# (array([[0.37444824, 0.37444855],
#         [0.33798878, 0.33798916]]),
#  array([[nan, nan],
#         [nan, nan]]))

# %%
nodel.q2_cv
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
nodel.paint_rmse_p(metrics_name="RMSE_P")
# Out:
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:66: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   x_lab.append(f'$10^{{{i.get_text()}}}$')
# /home/ferubkomsu/Рабочий стол/new_n_pls/paint_scripts/draw_valid_matrix_rus.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   #plt.xticks(indexx,lower,fontsize=20)
